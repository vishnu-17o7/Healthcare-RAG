# %%
import pandas as pd

# %%
groundwater = pd.read_csv(r"C:\Users\vishn\Desktop\Programs\CodeOClock\groundwater\ZIP\7063\7063_KEYS.csv")

# %%
groundwater.head()
# Out:
#       srcStateName srcDistrictName    srcMonth  srcYear  YearCode  \
# 0  JAMMU & KASHMIR        ANANTNAG  Apr - 2011     2011      2011
# 1  JAMMU & KASHMIR        ANANTNAG  Apr - 2012     2012      2012
# 2  JAMMU & KASHMIR        ANANTNAG  Apr - 2013     2013      2013
# 3  JAMMU & KASHMIR        ANANTNAG  Apr - 2014     2014      2014
# 4  JAMMU & KASHMIR        ANANTNAG  Apr - 2015     2015      2015
#
#                               Year  MonthCode        Month Country  StateCode  \
# 0  Calendar Year (Jan - Dec), 2011     201104  April, 2011   India          1
# 1  Calendar Year (Jan - Dec), 2012     201204  April, 2012   India          1
# 2  Calendar Year (Jan - Dec), 2013     201304  April, 2013   India          1
# 3  Calendar Year (Jan - Dec), 2014     201404  April, 2014   India          1
# 4  Calendar Year (Jan - Dec), 2015     201504  April, 2015   India          1
#
#    ... WeighingRatio_NumberOfHouseholdsUrban  \
# 0  ...                                   1.0
# ...

# %%
groundwater.describe()
# Out:
#              srcYear       YearCode      MonthCode      StateCode  \
# count  112751.000000  112751.000000  112751.000000  112751.000000
# mean     2016.218978    2016.218978  201628.270073      18.578372
# std         3.301674       3.301674     329.961813       9.760148
# min      2011.000000    2011.000000  201101.000000       1.000000
# 25%      2013.000000    2013.000000  201311.000000       9.000000
# 50%      2016.000000    2016.000000  201609.000000      19.000000
# 75%      2019.000000    2019.000000  201907.000000      27.000000
# max      2022.000000    2022.000000  202205.000000      38.000000
#
#         DistrictCode  TotalPopulation  TotalPopulationUrban  \
# count  112751.000000     1.120660e+05          1.120660e+05
# mean      379.091130     1.467716e+06          4.558965e+05
# std       213.179745     1.458577e+06          8.595787e+05
# min         1.000000     6.400000e+01          0.000000e+00
# 25%       199.000000     3.819560e+05          4.814000e+04
# ...
